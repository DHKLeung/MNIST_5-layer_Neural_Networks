# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import pandas as pd
from tensorflow.examples.tutorials.mnist import input_data
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all images and labels of train, validation, test dataset
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)
    data = {
        'train_images': mnist.train.images,
        'train_labels': mnist.train.labels,
        'validation_images': mnist.validation.images,
        'validation_labels': mnist.validation.labels,
        'test_images': mnist.test.images,
        'test_labels': mnist.test.labels
    }
    return data

# %%
"""
Perform Data Augmentation
Variables: images format = NHWC, labels format = NC, times = times for augmentation
Return: augmented dataset
"""
def data_augmentation(images, labels, times):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(
              rotation_range=15,
              zoom_range=0.1,
              width_shift_range=0.15,
              height_shift_range=0.15,
              data_format='channels_last'
    )
    counter = 0
    original_datasize = images.shape[0]
    for images_aug, labels_aug in datagen.flow(images, labels, batch_size=original_datasize, shuffle=False):
        if counter == times:
            break
        images = np.append(images, images_aug, axis=0)
        labels = np.append(labels, labels_aug, axis=0)
        counter += 1
    return images, labels

# %%
"""
Perform Data Shuffling
"""
def data_shuffling(images, labels):
    shuffle_array = np.random.permutation(images.shape[0])
    images = images[shuffle_array]
    labels = labels[shuffle_array]
    return images, labels

# %%
"""
Define the architecture of Neural Networks
"""
def neural_networks_model(images, n_1, n_2, n_3, n_4, n_out, keep_prob_1, keep_prob_2, keep_prob_3, keep_prob_4, is_training):
    with tf.variable_scope('nn_model'):
        A1 = tf.contrib.layers.fully_connected(images, n_1, scope='A1')
        A1_dropout = tf.contrib.layers.dropout(A1, keep_prob=keep_prob_1, is_training=is_training, scope='A1_dropout')
        A2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, scope='A2')
        A2_dropout = tf.contrib.layers.dropout(A2, keep_prob=keep_prob_2, is_training=is_training, scope='A2_dropout')
        A3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, scope='A3')
        A3_dropout = tf.contrib.layers.dropout(A3, keep_prob=keep_prob_3, is_training=is_training, scope='A3_dropout')
        A4 = tf.contrib.layers.fully_connected(A3_dropout, n_4, scope='A4')
        A4_dropout = tf.contrib.layers.dropout(A4, keep_prob=keep_prob_4, is_training=is_training, scope='A4_dropout')
        Z_out = tf.contrib.layers.fully_connected(A4_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Neural Networks Model
Return: history of costs
"""
def mnist_nn(hyperparams):
    tf.reset_default_graph()
    
    #Load, augment and shuffle data#
    data = load_data() 
    data['train_images'], data['train_labels'] = data_augmentation(data['train_images'].reshape(-1, 28, 28, 1), data['train_labels'], hyperparams['augment_times'])
    data['train_images'] = data['train_images'].reshape(-1, 784)
    data['train_images'], data['train_labels'] = data_shuffling(data['train_images'], data['train_labels'])
    
    #Hyperparameters settings and properties#
    learning_rate = hyperparams['learning_rate']
    decay_rate = hyperparams['decay_rate']
    decay_steps = hyperparams['decay_steps']
    epoch = hyperparams['epoch']
    keep_prob_1 = hyperparams['keep_prob_1']
    keep_prob_2 = hyperparams['keep_prob_2']
    keep_prob_3 = hyperparams['keep_prob_3']
    keep_prob_4 = hyperparams['keep_prob_4']
    n_1 = hyperparams['n_1']
    n_2 = hyperparams['n_2']
    n_3 = hyperparams['n_3']
    n_4 = hyperparams['n_4']
    n_out = hyperparams['n_out']
    batch_size = hyperparams['batch_size']
    train_data_size = data['train_images'].shape[0]
    validation_data_size = data['validation_images'].shape[0]
    test_data_size = data['test_images'].shape[0]
    image_size = data['train_images'].shape[1]
    label_size = data['train_labels'].shape[1]
    train_total_batches = np.ceil(train_data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    images_input = tf.placeholder(tf.float32, (None, image_size), name='images_input')
    labels = tf.placeholder(tf.float32, (None, label_size), name='labels')
    is_training = tf.placeholder(tf.bool, name='is_training')
    
    #Define model#
    model_out = neural_networks_model(images_input, n_1, n_2, n_3, n_4, n_out, keep_prob_1, keep_prob_2, keep_prob_3, keep_prob_4, is_training)
    
    #Define Cost, Predictions, Comparisons and Accuracy#
    softmax_cost = tf.nn.softmax_cross_entropy_with_logits(logits=model_out, labels=labels, name='softmax_cost')
    cost_sum = tf.reduce_sum(softmax_cost, name='cost_sum')
    cost_mean = tf.reduce_mean(softmax_cost, name='cost_mean')
    predictions = tf.argmax(model_out, axis=-1, name='predictions')
    labels_sparse = tf.argmax(labels, axis=-1, name='labels_sparse')
    comparisons = tf.cast(tf.equal(predictions, labels_sparse, name='pred_labels_comparison_bool'), tf.float32, name='pred_labels_comparison_float32')
    accuracy_sum = tf.reduce_sum(comparisons, name='accuracy_sum')
    accuracy_mean = tf.reduce_mean(comparisons, name='accuracy_mean')
    
    #Compute decayed learning rate#
    global_step = tf.Variable(0, trainable=False, name='global_step', dtype=tf.int32)
    decayed_learning_rate = tf.train.exponential_decay(learning_rate, global_step, decay_steps, decay_rate, staircase=False, name='decayed_learning_rate')
    
    #Define optimizer#
    opt_minimize = tf.train.AdamOptimizer(learning_rate=decayed_learning_rate, name='optimizer').minimize(cost_mean, global_step=global_step, name='opt_minimize')
    
    #Training#
    costs_history = {
        'train_cost_iter': [],
        'validation_cost_iter': []
    }
    accuracies_history = {
        'train_acc_iter': [],
        'validation_acc_iter': []
    }
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            
            #Reset the accumulators#
            train_cost_epoch = 0.
            train_acc_epoch = 0.
            validation_cost_epoch = 0.
            validation_acc_epoch = 0.
            for j in range(train_total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < train_data_size else train_data_size
                images_batch = data['train_images'][index_front:index_end]
                labels_batch = data['train_labels'][index_front:index_end]
                current_batch_size = index_end - index_front
                
                #Update parameters of the model#
                _, train_cost_iter, train_acc_iter = sess.run([opt_minimize, cost_sum, accuracy_sum], feed_dict={images_input:images_batch, labels:labels_batch, is_training:True})
                
                #Run on validation set#
                validation_cost_mean_iter, validation_acc_mean_iter = sess.run([cost_mean, accuracy_mean], feed_dict={images_input:data['validation_images'], labels:data['validation_labels'], is_training:False})
                
                #Compute and save the average(likely) costs and accuracies#
                train_cost_epoch += train_cost_iter / train_data_size
                train_acc_epoch += train_acc_iter / train_data_size
                train_cost_mean_iter = train_cost_iter / current_batch_size
                train_acc_mean_iter = train_acc_iter / current_batch_size
                costs_history['train_cost_iter'].append(train_cost_mean_iter)
                costs_history['validation_cost_iter'].append(validation_cost_mean_iter)
                accuracies_history['train_acc_iter'].append(train_acc_mean_iter)
                accuracies_history['validation_acc_iter'].append(validation_acc_mean_iter)
                
            #Print the state every epoch#
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Training Cost: {:.8f} Validation Cost: {:.8f} Training Accuracy: {:.4f} Validation Accuracy: {:.4f}'.format(train_cost_epoch, costs_history['validation_cost_iter'][-1], train_acc_epoch, accuracies_history['validation_acc_iter'][-1]))
        
        #Print the accuracy of running on test set#
        test_acc = sess.run(accuracy_mean, feed_dict={images_input:data['test_images'], labels:data['test_labels'], is_training:False})
        print('Testing Accuracy: {:.4f}'.format(test_acc))
    return costs_history, accuracies_history

# %%
"""
Show graphs of costs
"""
def show_costs_graphs(costs_history, ewma_span=10):
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Iteration')
    plt.title('Cost - Iteration')
    plt.plot(costs_history['train_cost_iter'], 'b-', alpha=0.3, label='Training Cost')
    plt.plot(costs_history['validation_cost_iter'], 'r-', alpha=0.3, label='Validation Cost')
    ewma_train_cost_iter = pd.stats.moments.ewma(np.array(costs_history['train_cost_iter']), span=ewma_span)
    plt.plot(ewma_train_cost_iter, 'b-', label='Training Cost EWMA')
    ewma_val_cost_iter = pd.stats.moments.ewma(np.array(costs_history['validation_cost_iter']), span=ewma_span)
    plt.plot(ewma_val_cost_iter, 'r-', label='Validation Cost EWMA')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show graphs of accuracies
"""
def show_accs_graphs(accuracies_history, ewma_span=10):
    plt.figure(figsize=(20, 10))
    plt.ylabel('Accuracy')
    plt.xlabel('Iteration')
    plt.title('Accuracy - Iteration')
    plt.plot(accuracies_history['train_acc_iter'], 'b-', alpha=0.3, label='Training Accuracy')
    plt.plot(accuracies_history['validation_acc_iter'], 'r-', alpha=0.3, label='Validation Accuracy')
    ewma_train_cost_iter = pd.stats.moments.ewma(np.array(accuracies_history['train_acc_iter']), span=ewma_span)
    plt.plot(ewma_train_cost_iter, 'b-', label='Training Accuracy EWMA')
    ewma_val_cost_iter = pd.stats.moments.ewma(np.array(accuracies_history['validation_acc_iter']), span=ewma_span)
    plt.plot(ewma_val_cost_iter, 'r-', label='Validation Accuracy EWMA')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'learning_rate': 0.001,
    'decay_rate': 0.95,
    'decay_steps': 2149,
    'epoch': 100,
    'keep_prob_1': 0.7,
    'keep_prob_2': 0.7,
    'keep_prob_3': 0.5,
    'keep_prob_4': 0.4,
    'n_1': 1024,
    'n_2': 512,
    'n_3': 256,
    'n_4': 128,
    'n_out': 10,
    'batch_size': 128,
    'augment_times': 4
}
costs_history, accuracies_history = mnist_nn(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 27.68s
# Training Cost: 0.54670717 Validation Cost: 0.08742519 Training Accuracy: 0.8300 Validation Accuracy: 0.9764
# Epoch 2/100 Time Elapsed: 27.49s
# Training Cost: 0.25285842 Validation Cost: 0.05941848 Training Accuracy: 0.9305 Validation Accuracy: 0.9818
# Epoch 3/100 Time Elapsed: 27.89s
# Training Cost: 0.20047988 Validation Cost: 0.04792707 Training Accuracy: 0.9444 Validation Accuracy: 0.9860
# Epoch 4/100 Time Elapsed: 27.77s
# Training Cost: 0.17033548 Validation Cost: 0.04664979 Training Accuracy: 0.9523 Validation Accuracy: 0.9868
# Epoch 5/100 Time Elapsed: 29.39s
# Training Cost: 0.14986452 Validation Cost: 0.04213742 Training Accuracy: 0.9577 Validation Accuracy: 0.9870
# Epoch 6/100 Time Elapsed: 28.03s
# Training Cost: 0.13199762 Validation Cost: 0.04125901 Training Accuracy: 0.9629 Validation Accuracy: 0.9888
# Epoch 7/100 Time Elapsed: 27.41s
# Training Cost: 0.11868085 Validation Cost: 0.04018067 Training Accuracy: 0.9666 Validation Accuracy: 0.9874
# Epoch 8/100 Time Elapsed: 27.29s
# Training Cost: 0.10800693 Validation Cost: 0.04335567 Training Accuracy: 0.9688 Validation Accuracy: 0.9882
# Epoch 9/100 Time Elapsed: 29.98s
# Training Cost: 0.09680481 Validation Cost: 0.03590329 Training Accuracy: 0.9722 Validation Accuracy: 0.9902
# Epoch 10/100 Time Elapsed: 27.78s
# Training Cost: 0.08824367 Validation Cost: 0.03963282 Training Accuracy: 0.9747 Validation Accuracy: 0.9900
# Epoch 11/100 Time Elapsed: 30.35s
# Training Cost: 0.08210478 Validation Cost: 0.03821953 Training Accuracy: 0.9767 Validation Accuracy: 0.9900
# Epoch 12/100 Time Elapsed: 29.72s
# Training Cost: 0.07573273 Validation Cost: 0.03301667 Training Accuracy: 0.9783 Validation Accuracy: 0.9908
# Epoch 13/100 Time Elapsed: 29.52s
# Training Cost: 0.06964487 Validation Cost: 0.04227543 Training Accuracy: 0.9799 Validation Accuracy: 0.9898
# Epoch 14/100 Time Elapsed: 27.63s
# Training Cost: 0.06604487 Validation Cost: 0.04133125 Training Accuracy: 0.9812 Validation Accuracy: 0.9890
# Epoch 15/100 Time Elapsed: 29.46s
# Training Cost: 0.06012152 Validation Cost: 0.03892063 Training Accuracy: 0.9827 Validation Accuracy: 0.9922
# Epoch 16/100 Time Elapsed: 28.57s
# Training Cost: 0.05740172 Validation Cost: 0.04211438 Training Accuracy: 0.9834 Validation Accuracy: 0.9902
# Epoch 17/100 Time Elapsed: 29.35s
# Training Cost: 0.05084052 Validation Cost: 0.04113554 Training Accuracy: 0.9852 Validation Accuracy: 0.9914
# Epoch 18/100 Time Elapsed: 30.53s
# Training Cost: 0.04856206 Validation Cost: 0.04084554 Training Accuracy: 0.9860 Validation Accuracy: 0.9920
# Epoch 19/100 Time Elapsed: 28.02s
# Training Cost: 0.04542457 Validation Cost: 0.03973627 Training Accuracy: 0.9866 Validation Accuracy: 0.9906
# Epoch 20/100 Time Elapsed: 29.07s
# Training Cost: 0.04296558 Validation Cost: 0.03941900 Training Accuracy: 0.9876 Validation Accuracy: 0.9918
# Epoch 21/100 Time Elapsed: 28.14s
# Training Cost: 0.04025385 Validation Cost: 0.03935280 Training Accuracy: 0.9882 Validation Accuracy: 0.9914
# Epoch 22/100 Time Elapsed: 28.38s
# Training Cost: 0.03865295 Validation Cost: 0.04143820 Training Accuracy: 0.9887 Validation Accuracy: 0.9916
# Epoch 23/100 Time Elapsed: 28.04s
# Training Cost: 0.03527430 Validation Cost: 0.04560861 Training Accuracy: 0.9896 Validation Accuracy: 0.9916
# Epoch 24/100 Time Elapsed: 28.98s
# Training Cost: 0.03311719 Validation Cost: 0.04308866 Training Accuracy: 0.9903 Validation Accuracy: 0.9924
# Epoch 25/100 Time Elapsed: 26.78s
# Training Cost: 0.03219852 Validation Cost: 0.04355095 Training Accuracy: 0.9909 Validation Accuracy: 0.9912
# Epoch 26/100 Time Elapsed: 30.75s
# Training Cost: 0.03001101 Validation Cost: 0.04868441 Training Accuracy: 0.9914 Validation Accuracy: 0.9910
# Epoch 27/100 Time Elapsed: 26.84s
# Training Cost: 0.02846699 Validation Cost: 0.04417915 Training Accuracy: 0.9918 Validation Accuracy: 0.9928
# Epoch 28/100 Time Elapsed: 28.50s
# Training Cost: 0.02629669 Validation Cost: 0.04539650 Training Accuracy: 0.9924 Validation Accuracy: 0.9928
# Epoch 29/100 Time Elapsed: 28.02s
# Training Cost: 0.02595275 Validation Cost: 0.04643767 Training Accuracy: 0.9925 Validation Accuracy: 0.9926
# Epoch 30/100 Time Elapsed: 28.74s
# Training Cost: 0.02623419 Validation Cost: 0.03929221 Training Accuracy: 0.9927 Validation Accuracy: 0.9924
# Epoch 31/100 Time Elapsed: 26.99s
# Training Cost: 0.02404789 Validation Cost: 0.04753519 Training Accuracy: 0.9931 Validation Accuracy: 0.9908
# Epoch 32/100 Time Elapsed: 28.16s
# Training Cost: 0.02161109 Validation Cost: 0.04968768 Training Accuracy: 0.9936 Validation Accuracy: 0.9918
# Epoch 33/100 Time Elapsed: 29.25s
# Training Cost: 0.02143682 Validation Cost: 0.05035221 Training Accuracy: 0.9940 Validation Accuracy: 0.9920
# Epoch 34/100 Time Elapsed: 28.89s
# Training Cost: 0.02129929 Validation Cost: 0.04223713 Training Accuracy: 0.9939 Validation Accuracy: 0.9924
# Epoch 35/100 Time Elapsed: 29.28s
# Training Cost: 0.01905545 Validation Cost: 0.05004817 Training Accuracy: 0.9943 Validation Accuracy: 0.9916
# Epoch 36/100 Time Elapsed: 28.48s
# Training Cost: 0.01951386 Validation Cost: 0.05238844 Training Accuracy: 0.9944 Validation Accuracy: 0.9920
# Epoch 37/100 Time Elapsed: 28.17s
# Training Cost: 0.01764820 Validation Cost: 0.04519739 Training Accuracy: 0.9947 Validation Accuracy: 0.9924
# Epoch 38/100 Time Elapsed: 27.99s
# Training Cost: 0.01734010 Validation Cost: 0.04635264 Training Accuracy: 0.9951 Validation Accuracy: 0.9924
# Epoch 39/100 Time Elapsed: 28.26s
# Training Cost: 0.01738349 Validation Cost: 0.05255035 Training Accuracy: 0.9953 Validation Accuracy: 0.9926
# Epoch 40/100 Time Elapsed: 29.54s
# Training Cost: 0.01646518 Validation Cost: 0.05311870 Training Accuracy: 0.9953 Validation Accuracy: 0.9916
# Epoch 41/100 Time Elapsed: 28.51s
# Training Cost: 0.01583866 Validation Cost: 0.04970376 Training Accuracy: 0.9955 Validation Accuracy: 0.9924
# Epoch 42/100 Time Elapsed: 28.00s
# Training Cost: 0.01539726 Validation Cost: 0.05041362 Training Accuracy: 0.9956 Validation Accuracy: 0.9920
# Epoch 43/100 Time Elapsed: 28.35s
# Training Cost: 0.01468579 Validation Cost: 0.05370837 Training Accuracy: 0.9959 Validation Accuracy: 0.9920
# Epoch 44/100 Time Elapsed: 29.06s
# Training Cost: 0.01429609 Validation Cost: 0.04994830 Training Accuracy: 0.9961 Validation Accuracy: 0.9922
# Epoch 45/100 Time Elapsed: 28.38s
# Training Cost: 0.01478554 Validation Cost: 0.05062081 Training Accuracy: 0.9960 Validation Accuracy: 0.9920
# Epoch 46/100 Time Elapsed: 29.21s
# Training Cost: 0.01359918 Validation Cost: 0.05114912 Training Accuracy: 0.9960 Validation Accuracy: 0.9922
# Epoch 47/100 Time Elapsed: 28.04s
# Training Cost: 0.01219323 Validation Cost: 0.05305504 Training Accuracy: 0.9966 Validation Accuracy: 0.9924
# Epoch 48/100 Time Elapsed: 27.95s
# Training Cost: 0.01343945 Validation Cost: 0.05260444 Training Accuracy: 0.9964 Validation Accuracy: 0.9926
# Epoch 49/100 Time Elapsed: 27.40s
# Training Cost: 0.01199972 Validation Cost: 0.05404755 Training Accuracy: 0.9966 Validation Accuracy: 0.9928
# Epoch 50/100 Time Elapsed: 28.38s
# Training Cost: 0.01165998 Validation Cost: 0.05470780 Training Accuracy: 0.9967 Validation Accuracy: 0.9928
# Epoch 51/100 Time Elapsed: 29.05s
# Training Cost: 0.01158825 Validation Cost: 0.05568853 Training Accuracy: 0.9970 Validation Accuracy: 0.9928
# Epoch 52/100 Time Elapsed: 28.88s
# Training Cost: 0.01105851 Validation Cost: 0.05672611 Training Accuracy: 0.9970 Validation Accuracy: 0.9928
# Epoch 53/100 Time Elapsed: 27.32s
# Training Cost: 0.01117437 Validation Cost: 0.05777828 Training Accuracy: 0.9969 Validation Accuracy: 0.9918
# Epoch 54/100 Time Elapsed: 27.27s
# Training Cost: 0.01106361 Validation Cost: 0.05926998 Training Accuracy: 0.9969 Validation Accuracy: 0.9924
# Epoch 55/100 Time Elapsed: 28.64s
# Training Cost: 0.01120689 Validation Cost: 0.05788080 Training Accuracy: 0.9969 Validation Accuracy: 0.9926
# Epoch 56/100 Time Elapsed: 27.83s
# Training Cost: 0.01068332 Validation Cost: 0.05847465 Training Accuracy: 0.9971 Validation Accuracy: 0.9926
# Epoch 57/100 Time Elapsed: 27.34s
# Training Cost: 0.01074510 Validation Cost: 0.05736809 Training Accuracy: 0.9971 Validation Accuracy: 0.9918
# Epoch 58/100 Time Elapsed: 30.67s
# Training Cost: 0.01041528 Validation Cost: 0.05896309 Training Accuracy: 0.9971 Validation Accuracy: 0.9920
# Epoch 59/100 Time Elapsed: 28.53s
# Training Cost: 0.00964623 Validation Cost: 0.06006338 Training Accuracy: 0.9973 Validation Accuracy: 0.9928
# Epoch 60/100 Time Elapsed: 27.68s
# Training Cost: 0.01002409 Validation Cost: 0.05860082 Training Accuracy: 0.9972 Validation Accuracy: 0.9924
# Epoch 61/100 Time Elapsed: 27.52s
# Training Cost: 0.00990211 Validation Cost: 0.05892812 Training Accuracy: 0.9973 Validation Accuracy: 0.9928
# Epoch 62/100 Time Elapsed: 26.64s
# Training Cost: 0.00975702 Validation Cost: 0.05642219 Training Accuracy: 0.9972 Validation Accuracy: 0.9926
# Epoch 63/100 Time Elapsed: 28.52s
# Training Cost: 0.00998974 Validation Cost: 0.05763802 Training Accuracy: 0.9974 Validation Accuracy: 0.9928
# Epoch 64/100 Time Elapsed: 28.56s
# Training Cost: 0.00907542 Validation Cost: 0.05582798 Training Accuracy: 0.9974 Validation Accuracy: 0.9928
# Epoch 65/100 Time Elapsed: 28.45s
# Training Cost: 0.00941065 Validation Cost: 0.05529664 Training Accuracy: 0.9974 Validation Accuracy: 0.9926
# Epoch 66/100 Time Elapsed: 27.65s
# Training Cost: 0.00893488 Validation Cost: 0.05655072 Training Accuracy: 0.9975 Validation Accuracy: 0.9924
# Epoch 67/100 Time Elapsed: 27.22s
# Training Cost: 0.00876047 Validation Cost: 0.05608486 Training Accuracy: 0.9975 Validation Accuracy: 0.9924
# Epoch 68/100 Time Elapsed: 27.87s
# Training Cost: 0.00890586 Validation Cost: 0.05591306 Training Accuracy: 0.9976 Validation Accuracy: 0.9926
# Epoch 69/100 Time Elapsed: 29.66s
# Training Cost: 0.00945543 Validation Cost: 0.05591685 Training Accuracy: 0.9975 Validation Accuracy: 0.9922
# Epoch 70/100 Time Elapsed: 28.47s
# Training Cost: 0.00831449 Validation Cost: 0.05725453 Training Accuracy: 0.9976 Validation Accuracy: 0.9922
# Epoch 71/100 Time Elapsed: 28.10s
# Training Cost: 0.00855830 Validation Cost: 0.05586401 Training Accuracy: 0.9977 Validation Accuracy: 0.9922
# Epoch 72/100 Time Elapsed: 30.18s
# Training Cost: 0.00807353 Validation Cost: 0.05490455 Training Accuracy: 0.9977 Validation Accuracy: 0.9920
# Epoch 73/100 Time Elapsed: 26.73s
# Training Cost: 0.00896501 Validation Cost: 0.05685017 Training Accuracy: 0.9977 Validation Accuracy: 0.9924
# Epoch 74/100 Time Elapsed: 27.49s
# Training Cost: 0.00885679 Validation Cost: 0.05689862 Training Accuracy: 0.9976 Validation Accuracy: 0.9922
# Epoch 75/100 Time Elapsed: 28.90s
# Training Cost: 0.00852413 Validation Cost: 0.05731459 Training Accuracy: 0.9977 Validation Accuracy: 0.9918
# Epoch 76/100 Time Elapsed: 28.30s
# Training Cost: 0.00829969 Validation Cost: 0.05790673 Training Accuracy: 0.9977 Validation Accuracy: 0.9924
# Epoch 77/100 Time Elapsed: 27.48s
# Training Cost: 0.00805101 Validation Cost: 0.05733413 Training Accuracy: 0.9979 Validation Accuracy: 0.9922
# Epoch 78/100 Time Elapsed: 29.09s
# Training Cost: 0.00858339 Validation Cost: 0.05629575 Training Accuracy: 0.9977 Validation Accuracy: 0.9924
# Epoch 79/100 Time Elapsed: 28.93s
# Training Cost: 0.00773718 Validation Cost: 0.05581075 Training Accuracy: 0.9978 Validation Accuracy: 0.9924
# Epoch 80/100 Time Elapsed: 27.35s
# Training Cost: 0.00770280 Validation Cost: 0.05594508 Training Accuracy: 0.9978 Validation Accuracy: 0.9926
# Epoch 81/100 Time Elapsed: 29.60s
# Training Cost: 0.00765362 Validation Cost: 0.05656461 Training Accuracy: 0.9979 Validation Accuracy: 0.9924
# Epoch 82/100 Time Elapsed: 28.00s
# Training Cost: 0.00833620 Validation Cost: 0.05745370 Training Accuracy: 0.9978 Validation Accuracy: 0.9926
# Epoch 83/100 Time Elapsed: 28.82s
# Training Cost: 0.00821180 Validation Cost: 0.05760285 Training Accuracy: 0.9979 Validation Accuracy: 0.9920
# Epoch 84/100 Time Elapsed: 28.18s
# Training Cost: 0.00768714 Validation Cost: 0.05741231 Training Accuracy: 0.9979 Validation Accuracy: 0.9924
# Epoch 85/100 Time Elapsed: 26.71s
# Training Cost: 0.00773236 Validation Cost: 0.05593869 Training Accuracy: 0.9978 Validation Accuracy: 0.9926
# Epoch 86/100 Time Elapsed: 27.94s
# Training Cost: 0.00731188 Validation Cost: 0.05617914 Training Accuracy: 0.9980 Validation Accuracy: 0.9924
# Epoch 87/100 Time Elapsed: 28.52s
# Training Cost: 0.00820193 Validation Cost: 0.05629400 Training Accuracy: 0.9979 Validation Accuracy: 0.9920
# Epoch 88/100 Time Elapsed: 30.39s
# Training Cost: 0.00797348 Validation Cost: 0.05584041 Training Accuracy: 0.9979 Validation Accuracy: 0.9922
# Epoch 89/100 Time Elapsed: 28.15s
# Training Cost: 0.00754576 Validation Cost: 0.05639359 Training Accuracy: 0.9980 Validation Accuracy: 0.9922
# Epoch 90/100 Time Elapsed: 27.06s
# Training Cost: 0.00800308 Validation Cost: 0.05649472 Training Accuracy: 0.9979 Validation Accuracy: 0.9926
# Epoch 91/100 Time Elapsed: 27.22s
# Training Cost: 0.00789021 Validation Cost: 0.05770748 Training Accuracy: 0.9979 Validation Accuracy: 0.9922
# Epoch 92/100 Time Elapsed: 30.63s
# Training Cost: 0.00747057 Validation Cost: 0.05768425 Training Accuracy: 0.9979 Validation Accuracy: 0.9920
# Epoch 93/100 Time Elapsed: 27.71s
# Training Cost: 0.00804166 Validation Cost: 0.05775685 Training Accuracy: 0.9979 Validation Accuracy: 0.9920
# Epoch 94/100 Time Elapsed: 27.17s
# Training Cost: 0.00691638 Validation Cost: 0.05834531 Training Accuracy: 0.9981 Validation Accuracy: 0.9922
# Epoch 95/100 Time Elapsed: 31.03s
# Training Cost: 0.00732983 Validation Cost: 0.05843995 Training Accuracy: 0.9979 Validation Accuracy: 0.9922
# Epoch 96/100 Time Elapsed: 29.86s
# Training Cost: 0.00804114 Validation Cost: 0.05761611 Training Accuracy: 0.9978 Validation Accuracy: 0.9920
# Epoch 97/100 Time Elapsed: 28.51s
# Training Cost: 0.00723002 Validation Cost: 0.05755530 Training Accuracy: 0.9980 Validation Accuracy: 0.9924
# Epoch 98/100 Time Elapsed: 29.22s
# Training Cost: 0.00757390 Validation Cost: 0.05883291 Training Accuracy: 0.9981 Validation Accuracy: 0.9922
# Epoch 99/100 Time Elapsed: 27.53s
# Training Cost: 0.00767998 Validation Cost: 0.05805168 Training Accuracy: 0.9979 Validation Accuracy: 0.9922
# Epoch 100/100 Time Elapsed: 27.76s
# Training Cost: 0.00701778 Validation Cost: 0.05814307 Training Accuracy: 0.9981 Validation Accuracy: 0.9922
# Testing Accuracy: 0.9916

# %%
show_costs_graphs(costs_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   del sys.path[0]

# %%
show_accs_graphs(accuracies_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   del sys.path[0]
