# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import pandas as pd
from tensorflow.examples.tutorials.mnist import input_data
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
"""
Compute the time elapsed
"""
def tic():
    global tic_time
    tic_time = time.time()
    
def toc():
    return time.time() - tic_time

# %%
"""
Load MNIST data
Return: all images and labels of train, validation, test dataset
"""
def load_data():
    mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)
    data = {
        'train_images': mnist.train.images,
        'train_labels': mnist.train.labels,
        'validation_images': mnist.validation.images,
        'validation_labels': mnist.validation.labels,
        'test_images': mnist.test.images,
        'test_labels': mnist.test.labels
    }
    return data

# %%
"""
Perform Data Augmentation
Variables: images format = NHWC, labels format = NC, times = times for augmentation
Return: augmented dataset
"""
def data_augmentation(images, labels, times):
    datagen = tf.keras.preprocessing.image.ImageDataGenerator(
              rotation_range=15,
              zoom_range=0.1,
              width_shift_range=0.15,
              height_shift_range=0.15,
              data_format='channels_last'
    )
    counter = 0
    original_datasize = images.shape[0]
    for images_aug, labels_aug in datagen.flow(images, labels, batch_size=original_datasize, shuffle=False):
        if counter == times:
            break
        images = np.append(images, images_aug, axis=0)
        labels = np.append(labels, labels_aug, axis=0)
        counter += 1
    return images, labels

# %%
"""
Perform Data Shuffling
"""
def data_shuffling(images, labels):
    shuffle_array = np.random.permutation(images.shape[0])
    images = images[shuffle_array]
    labels = labels[shuffle_array]
    return images, labels

# %%
"""
Define the architecture of Neural Networks
"""
def neural_networks_model(images, n_1, n_2, n_3, n_4, n_out, keep_prob_1, keep_prob_2, keep_prob_3, keep_prob_4, is_training):
    with tf.variable_scope('nn_model'):
        A1 = tf.contrib.layers.fully_connected(images, n_1, scope='A1')
        A1_dropout = tf.contrib.layers.dropout(A1, keep_prob=keep_prob_1, is_training=is_training, scope='A1_dropout')
        A2 = tf.contrib.layers.fully_connected(A1_dropout, n_2, scope='A2')
        A2_dropout = tf.contrib.layers.dropout(A2, keep_prob=keep_prob_2, is_training=is_training, scope='A2_dropout')
        A3 = tf.contrib.layers.fully_connected(A2_dropout, n_3, scope='A3')
        A3_dropout = tf.contrib.layers.dropout(A3, keep_prob=keep_prob_3, is_training=is_training, scope='A3_dropout')
        A4 = tf.contrib.layers.fully_connected(A3_dropout, n_4, scope='A4')
        A4_dropout = tf.contrib.layers.dropout(A4, keep_prob=keep_prob_4, is_training=is_training, scope='A4_dropout')
        Z_out = tf.contrib.layers.fully_connected(A4_dropout, n_out, activation_fn=None, scope='Z_out')
    return Z_out

# %%
"""
Define and Train Neural Networks Model
Return: history of costs
"""
def mnist_nn(hyperparams):
    tf.reset_default_graph()
    
    #Load, augment and shuffle data#
    data = load_data() 
    data['train_images'], data['train_labels'] = data_augmentation(data['train_images'].reshape(-1, 28, 28, 1), data['train_labels'], hyperparams['augment_times'])
    data['train_images'] = data['train_images'].reshape(-1, 784)
    data['train_images'], data['train_labels'] = data_shuffling(data['train_images'], data['train_labels'])
    
    #Hyperparameters settings and properties#
    learning_rate = hyperparams['learning_rate']
    decay_rate = hyperparams['decay_rate']
    decay_steps = hyperparams['decay_steps']
    epoch = hyperparams['epoch']
    keep_prob_1 = hyperparams['keep_prob_1']
    keep_prob_2 = hyperparams['keep_prob_2']
    keep_prob_3 = hyperparams['keep_prob_3']
    keep_prob_4 = hyperparams['keep_prob_4']
    n_1 = hyperparams['n_1']
    n_2 = hyperparams['n_2']
    n_3 = hyperparams['n_3']
    n_4 = hyperparams['n_4']
    n_out = hyperparams['n_out']
    batch_size = hyperparams['batch_size']
    train_data_size = data['train_images'].shape[0]
    validation_data_size = data['validation_images'].shape[0]
    test_data_size = data['test_images'].shape[0]
    image_size = data['train_images'].shape[1]
    label_size = data['train_labels'].shape[1]
    train_total_batches = np.ceil(train_data_size / batch_size).astype(np.int32)
    
    #Define placeholders#
    images_input = tf.placeholder(tf.float32, (None, image_size), name='images_input')
    labels = tf.placeholder(tf.float32, (None, label_size), name='labels')
    is_training = tf.placeholder(tf.bool, name='is_training')
    
    #Define model#
    model_out = neural_networks_model(images_input, n_1, n_2, n_3, n_4, n_out, keep_prob_1, keep_prob_2, keep_prob_3, keep_prob_4, is_training)
    
    #Define Cost, Predictions, Comparisons and Accuracy#
    softmax_cost = tf.nn.softmax_cross_entropy_with_logits(logits=model_out, labels=labels, name='softmax_cost')
    cost_sum = tf.reduce_sum(softmax_cost, name='cost_sum')
    cost_mean = tf.reduce_mean(softmax_cost, name='cost_mean')
    predictions = tf.argmax(model_out, axis=-1, name='predictions')
    labels_sparse = tf.argmax(labels, axis=-1, name='labels_sparse')
    comparisons = tf.cast(tf.equal(predictions, labels_sparse, name='pred_labels_comparison_bool'), tf.float32, name='pred_labels_comparison_float32')
    accuracy_sum = tf.reduce_sum(comparisons, name='accuracy_sum')
    accuracy_mean = tf.reduce_mean(comparisons, name='accuracy_mean')
    
    #Compute decayed learning rate#
    global_step = tf.Variable(0, trainable=False, name='global_step', dtype=tf.int32)
    decayed_learning_rate = tf.train.exponential_decay(learning_rate, global_step, decay_steps, decay_rate, staircase=False, name='decayed_learning_rate')
    
    #Define optimizer#
    opt_minimize = tf.train.AdamOptimizer(learning_rate=decayed_learning_rate, name='optimizer').minimize(cost_mean, global_step=global_step, name='opt_minimize')
    
    #Training#
    costs_history = {
        'train_cost_iter': [],
        'validation_cost_iter': []
    }
    accuracies_history = {
        'train_acc_iter': [],
        'validation_acc_iter': []
    }
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(epoch):
            tic()
            
            #Reset the accumulators#
            train_cost_epoch = 0.
            train_acc_epoch = 0.
            validation_cost_epoch = 0.
            validation_acc_epoch = 0.
            for j in range(train_total_batches):
                index_front = j * batch_size
                index_end = (j + 1) * batch_size if (j + 1) * batch_size < train_data_size else train_data_size
                images_batch = data['train_images'][index_front:index_end]
                labels_batch = data['train_labels'][index_front:index_end]
                current_batch_size = index_end - index_front
                
                #Update parameters of the model#
                _, train_cost_iter, train_acc_iter = sess.run([opt_minimize, cost_sum, accuracy_sum], feed_dict={images_input:images_batch, labels:labels_batch, is_training:True})
                
                #Run on validation set#
                validation_cost_mean_iter, validation_acc_mean_iter = sess.run([cost_mean, accuracy_mean], feed_dict={images_input:data['validation_images'], labels:data['validation_labels'], is_training:False})
                
                #Compute and save the average(likely) costs and accuracies#
                train_cost_epoch += train_cost_iter / train_data_size
                train_acc_epoch += train_acc_iter / train_data_size
                train_cost_mean_iter = train_cost_iter / current_batch_size
                train_acc_mean_iter = train_acc_iter / current_batch_size
                costs_history['train_cost_iter'].append(train_cost_mean_iter)
                costs_history['validation_cost_iter'].append(validation_cost_mean_iter)
                accuracies_history['train_acc_iter'].append(train_acc_mean_iter)
                accuracies_history['validation_acc_iter'].append(validation_acc_mean_iter)
                
            #Print the state every epoch#
            print('Epoch {}/{} Time Elapsed: {:.2f}s'.format(i + 1, epoch, toc()))
            print('Training Cost: {:.8f} Validation Cost: {:.8f} Training Accuracy: {:.4f} Validation Accuracy: {:.4f}'.format(train_cost_epoch, costs_history['validation_cost_iter'][-1], train_acc_epoch, accuracies_history['validation_acc_iter'][-1]))
        
        #Print the accuracy of running on test set#
        test_acc = sess.run(accuracy_mean, feed_dict={images_input:data['test_images'], labels:data['test_labels'], is_training:False})
        print('Testing Accuracy: {:.4f}'.format(test_acc))
    return costs_history, accuracies_history

# %%
"""
Show graphs of costs
"""
def show_costs_graphs(costs_history, ewma_span=10):
    plt.figure(figsize=(20, 10))
    plt.ylabel('Cost')
    plt.xlabel('Iteration')
    plt.title('Cost - Iteration')
    plt.plot(costs_history['train_cost_iter'], 'b-', alpha=0.3, label='Training Cost')
    plt.plot(costs_history['validation_cost_iter'], 'r-', alpha=0.3, label='Validation Cost')
    ewma_train_cost_iter = pd.stats.moments.ewma(np.array(costs_history['train_cost_iter']), span=ewma_span)
    plt.plot(ewma_train_cost_iter, 'b-', label='Training Cost EWMA')
    ewma_val_cost_iter = pd.stats.moments.ewma(np.array(costs_history['validation_cost_iter']), span=ewma_span)
    plt.plot(ewma_val_cost_iter, 'r-', label='Validation Cost EWMA')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Show graphs of accuracies
"""
def show_accs_graphs(accuracies_history, ewma_span=10):
    plt.figure(figsize=(20, 10))
    plt.ylabel('Accuracy')
    plt.xlabel('Iteration')
    plt.title('Accuracy - Iteration')
    plt.plot(accuracies_history['train_acc_iter'], 'b-', alpha=0.3, label='Training Accuracy')
    plt.plot(accuracies_history['validation_acc_iter'], 'r-', alpha=0.3, label='Validation Accuracy')
    ewma_train_cost_iter = pd.stats.moments.ewma(np.array(accuracies_history['train_acc_iter']), span=ewma_span)
    plt.plot(ewma_train_cost_iter, 'b-', label='Training Accuracy EWMA')
    ewma_val_cost_iter = pd.stats.moments.ewma(np.array(accuracies_history['validation_acc_iter']), span=ewma_span)
    plt.plot(ewma_val_cost_iter, 'r-', label='Validation Accuracy EWMA')
    plt.legend(loc='best')
    plt.show()

# %%
"""
Define the hyperparameters
"""
hyperparams={
    'learning_rate': 0.001,
    'decay_rate': 0.95,
    'decay_steps': 2149,
    'epoch': 100,
    'keep_prob_1': 0.9,
    'keep_prob_2': 0.9,
    'keep_prob_3': 0.7,
    'keep_prob_4': 0.5,
    'n_1': 1024,
    'n_2': 512,
    'n_3': 256,
    'n_4': 128,
    'n_out': 10,
    'batch_size': 128,
    'augment_times': 4
}
costs_history, accuracies_history = mnist_nn(hyperparams)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Epoch 1/100 Time Elapsed: 27.84s
# Training Cost: 0.37215763 Validation Cost: 0.06703871 Training Accuracy: 0.8875 Validation Accuracy: 0.9806
# Epoch 2/100 Time Elapsed: 27.28s
# Training Cost: 0.16080721 Validation Cost: 0.05287255 Training Accuracy: 0.9533 Validation Accuracy: 0.9868
# Epoch 3/100 Time Elapsed: 28.84s
# Training Cost: 0.11764129 Validation Cost: 0.05277338 Training Accuracy: 0.9654 Validation Accuracy: 0.9868
# Epoch 4/100 Time Elapsed: 26.70s
# Training Cost: 0.09329899 Validation Cost: 0.05923862 Training Accuracy: 0.9722 Validation Accuracy: 0.9856
# Epoch 5/100 Time Elapsed: 27.86s
# Training Cost: 0.07648315 Validation Cost: 0.05105196 Training Accuracy: 0.9770 Validation Accuracy: 0.9876
# Epoch 6/100 Time Elapsed: 28.00s
# Training Cost: 0.06252285 Validation Cost: 0.04786455 Training Accuracy: 0.9808 Validation Accuracy: 0.9892
# Epoch 7/100 Time Elapsed: 27.03s
# Training Cost: 0.05312976 Validation Cost: 0.05508346 Training Accuracy: 0.9840 Validation Accuracy: 0.9880
# Epoch 8/100 Time Elapsed: 28.24s
# Training Cost: 0.04567730 Validation Cost: 0.05449681 Training Accuracy: 0.9859 Validation Accuracy: 0.9898
# Epoch 9/100 Time Elapsed: 28.98s
# Training Cost: 0.03941693 Validation Cost: 0.05679160 Training Accuracy: 0.9878 Validation Accuracy: 0.9894
# Epoch 10/100 Time Elapsed: 29.29s
# Training Cost: 0.03524136 Validation Cost: 0.05692929 Training Accuracy: 0.9894 Validation Accuracy: 0.9890
# Epoch 11/100 Time Elapsed: 29.38s
# Training Cost: 0.02970320 Validation Cost: 0.06092011 Training Accuracy: 0.9908 Validation Accuracy: 0.9890
# Epoch 12/100 Time Elapsed: 29.61s
# Training Cost: 0.02752206 Validation Cost: 0.05235369 Training Accuracy: 0.9916 Validation Accuracy: 0.9888
# Epoch 13/100 Time Elapsed: 28.49s
# Training Cost: 0.02360114 Validation Cost: 0.06778700 Training Accuracy: 0.9927 Validation Accuracy: 0.9886
# Epoch 14/100 Time Elapsed: 27.60s
# Training Cost: 0.02149999 Validation Cost: 0.06825784 Training Accuracy: 0.9934 Validation Accuracy: 0.9892
# Epoch 15/100 Time Elapsed: 27.74s
# Training Cost: 0.01851094 Validation Cost: 0.06773699 Training Accuracy: 0.9943 Validation Accuracy: 0.9906
# Epoch 16/100 Time Elapsed: 29.08s
# Training Cost: 0.01693663 Validation Cost: 0.07038813 Training Accuracy: 0.9951 Validation Accuracy: 0.9904
# Epoch 17/100 Time Elapsed: 29.34s
# Training Cost: 0.01606335 Validation Cost: 0.06644376 Training Accuracy: 0.9952 Validation Accuracy: 0.9914
# Epoch 18/100 Time Elapsed: 28.36s
# Training Cost: 0.01337663 Validation Cost: 0.06654211 Training Accuracy: 0.9960 Validation Accuracy: 0.9904
# Epoch 19/100 Time Elapsed: 27.61s
# Training Cost: 0.01270497 Validation Cost: 0.06686963 Training Accuracy: 0.9962 Validation Accuracy: 0.9908
# Epoch 20/100 Time Elapsed: 27.65s
# Training Cost: 0.01105495 Validation Cost: 0.06824490 Training Accuracy: 0.9966 Validation Accuracy: 0.9904
# Epoch 21/100 Time Elapsed: 28.94s
# Training Cost: 0.01091286 Validation Cost: 0.07411387 Training Accuracy: 0.9966 Validation Accuracy: 0.9902
# Epoch 22/100 Time Elapsed: 28.40s
# Training Cost: 0.00887615 Validation Cost: 0.07856393 Training Accuracy: 0.9974 Validation Accuracy: 0.9906
# Epoch 23/100 Time Elapsed: 28.84s
# Training Cost: 0.00803171 Validation Cost: 0.08865876 Training Accuracy: 0.9976 Validation Accuracy: 0.9902
# Epoch 24/100 Time Elapsed: 27.39s
# Training Cost: 0.00834261 Validation Cost: 0.07817315 Training Accuracy: 0.9977 Validation Accuracy: 0.9914
# Epoch 25/100 Time Elapsed: 27.25s
# Training Cost: 0.00699042 Validation Cost: 0.08103905 Training Accuracy: 0.9980 Validation Accuracy: 0.9910
# Epoch 26/100 Time Elapsed: 27.37s
# Training Cost: 0.00653951 Validation Cost: 0.08438932 Training Accuracy: 0.9981 Validation Accuracy: 0.9918
# Epoch 27/100 Time Elapsed: 28.20s
# Training Cost: 0.00625981 Validation Cost: 0.08532964 Training Accuracy: 0.9983 Validation Accuracy: 0.9900
# Epoch 28/100 Time Elapsed: 28.68s
# Training Cost: 0.00554585 Validation Cost: 0.08133049 Training Accuracy: 0.9983 Validation Accuracy: 0.9896
# Epoch 29/100 Time Elapsed: 28.31s
# Training Cost: 0.00532540 Validation Cost: 0.08794945 Training Accuracy: 0.9984 Validation Accuracy: 0.9900
# Epoch 30/100 Time Elapsed: 28.38s
# Training Cost: 0.00463142 Validation Cost: 0.08067250 Training Accuracy: 0.9987 Validation Accuracy: 0.9910
# Epoch 31/100 Time Elapsed: 27.24s
# Training Cost: 0.00427796 Validation Cost: 0.08413982 Training Accuracy: 0.9988 Validation Accuracy: 0.9908
# Epoch 32/100 Time Elapsed: 27.65s
# Training Cost: 0.00434600 Validation Cost: 0.08710382 Training Accuracy: 0.9988 Validation Accuracy: 0.9922
# Epoch 33/100 Time Elapsed: 28.82s
# Training Cost: 0.00403886 Validation Cost: 0.09331559 Training Accuracy: 0.9989 Validation Accuracy: 0.9906
# Epoch 34/100 Time Elapsed: 27.77s
# Training Cost: 0.00331719 Validation Cost: 0.07782859 Training Accuracy: 0.9991 Validation Accuracy: 0.9916
# Epoch 35/100 Time Elapsed: 30.17s
# Training Cost: 0.00315113 Validation Cost: 0.08900812 Training Accuracy: 0.9992 Validation Accuracy: 0.9908
# Epoch 36/100 Time Elapsed: 28.13s
# Training Cost: 0.00306755 Validation Cost: 0.08834032 Training Accuracy: 0.9991 Validation Accuracy: 0.9914
# Epoch 37/100 Time Elapsed: 26.83s
# Training Cost: 0.00250127 Validation Cost: 0.10079153 Training Accuracy: 0.9993 Validation Accuracy: 0.9902
# Epoch 38/100 Time Elapsed: 27.64s
# Training Cost: 0.00308282 Validation Cost: 0.08733013 Training Accuracy: 0.9993 Validation Accuracy: 0.9904
# Epoch 39/100 Time Elapsed: 27.92s
# Training Cost: 0.00251739 Validation Cost: 0.08955155 Training Accuracy: 0.9993 Validation Accuracy: 0.9918
# Epoch 40/100 Time Elapsed: 27.57s
# Training Cost: 0.00237610 Validation Cost: 0.08634673 Training Accuracy: 0.9993 Validation Accuracy: 0.9920
# Epoch 41/100 Time Elapsed: 26.98s
# Training Cost: 0.00231262 Validation Cost: 0.09615081 Training Accuracy: 0.9994 Validation Accuracy: 0.9932
# Epoch 42/100 Time Elapsed: 29.22s
# Training Cost: 0.00231230 Validation Cost: 0.08739851 Training Accuracy: 0.9994 Validation Accuracy: 0.9924
# Epoch 43/100 Time Elapsed: 28.43s
# Training Cost: 0.00226704 Validation Cost: 0.09884936 Training Accuracy: 0.9994 Validation Accuracy: 0.9914
# Epoch 44/100 Time Elapsed: 27.73s
# Training Cost: 0.00204459 Validation Cost: 0.10167746 Training Accuracy: 0.9995 Validation Accuracy: 0.9914
# Epoch 45/100 Time Elapsed: 26.72s
# Training Cost: 0.00168414 Validation Cost: 0.09820266 Training Accuracy: 0.9996 Validation Accuracy: 0.9918
# Epoch 46/100 Time Elapsed: 28.24s
# Training Cost: 0.00137480 Validation Cost: 0.10395271 Training Accuracy: 0.9996 Validation Accuracy: 0.9926
# Epoch 47/100 Time Elapsed: 27.13s
# Training Cost: 0.00189417 Validation Cost: 0.11195301 Training Accuracy: 0.9996 Validation Accuracy: 0.9912
# Epoch 48/100 Time Elapsed: 28.90s
# Training Cost: 0.00178715 Validation Cost: 0.10869463 Training Accuracy: 0.9996 Validation Accuracy: 0.9920
# Epoch 49/100 Time Elapsed: 28.90s
# Training Cost: 0.00125062 Validation Cost: 0.10265538 Training Accuracy: 0.9997 Validation Accuracy: 0.9908
# Epoch 50/100 Time Elapsed: 28.60s
# Training Cost: 0.00137024 Validation Cost: 0.11111499 Training Accuracy: 0.9996 Validation Accuracy: 0.9914
# Epoch 51/100 Time Elapsed: 26.36s
# Training Cost: 0.00117406 Validation Cost: 0.11318197 Training Accuracy: 0.9997 Validation Accuracy: 0.9914
# Epoch 52/100 Time Elapsed: 29.33s
# Training Cost: 0.00163594 Validation Cost: 0.11257640 Training Accuracy: 0.9996 Validation Accuracy: 0.9916
# Epoch 53/100 Time Elapsed: 31.12s
# Training Cost: 0.00107808 Validation Cost: 0.10735518 Training Accuracy: 0.9997 Validation Accuracy: 0.9922
# Epoch 54/100 Time Elapsed: 27.77s
# Training Cost: 0.00093621 Validation Cost: 0.11448496 Training Accuracy: 0.9997 Validation Accuracy: 0.9920
# Epoch 55/100 Time Elapsed: 28.68s
# Training Cost: 0.00081230 Validation Cost: 0.12014151 Training Accuracy: 0.9998 Validation Accuracy: 0.9916
# Epoch 56/100 Time Elapsed: 28.71s
# Training Cost: 0.00093104 Validation Cost: 0.11773059 Training Accuracy: 0.9997 Validation Accuracy: 0.9914
# Epoch 57/100 Time Elapsed: 30.07s
# Training Cost: 0.00083469 Validation Cost: 0.11570539 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 58/100 Time Elapsed: 29.40s
# Training Cost: 0.00114040 Validation Cost: 0.11476745 Training Accuracy: 0.9997 Validation Accuracy: 0.9910
# Epoch 59/100 Time Elapsed: 27.77s
# Training Cost: 0.00085242 Validation Cost: 0.11866584 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 60/100 Time Elapsed: 28.77s
# Training Cost: 0.00123725 Validation Cost: 0.12287021 Training Accuracy: 0.9997 Validation Accuracy: 0.9910
# Epoch 61/100 Time Elapsed: 26.86s
# Training Cost: 0.00072824 Validation Cost: 0.12434915 Training Accuracy: 0.9998 Validation Accuracy: 0.9906
# Epoch 62/100 Time Elapsed: 28.50s
# Training Cost: 0.00071338 Validation Cost: 0.12567945 Training Accuracy: 0.9998 Validation Accuracy: 0.9904
# Epoch 63/100 Time Elapsed: 29.42s
# Training Cost: 0.00074557 Validation Cost: 0.12270217 Training Accuracy: 0.9998 Validation Accuracy: 0.9904
# Epoch 64/100 Time Elapsed: 27.72s
# Training Cost: 0.00082741 Validation Cost: 0.12545557 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 65/100 Time Elapsed: 28.38s
# Training Cost: 0.00071621 Validation Cost: 0.12707363 Training Accuracy: 0.9999 Validation Accuracy: 0.9918
# Epoch 66/100 Time Elapsed: 29.76s
# Training Cost: 0.00088869 Validation Cost: 0.12881051 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 67/100 Time Elapsed: 27.36s
# Training Cost: 0.00079977 Validation Cost: 0.12844570 Training Accuracy: 0.9998 Validation Accuracy: 0.9908
# Epoch 68/100 Time Elapsed: 29.59s
# Training Cost: 0.00084051 Validation Cost: 0.12504365 Training Accuracy: 0.9998 Validation Accuracy: 0.9914
# Epoch 69/100 Time Elapsed: 28.66s
# Training Cost: 0.00089484 Validation Cost: 0.12154002 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 70/100 Time Elapsed: 26.79s
# Training Cost: 0.00053903 Validation Cost: 0.12396171 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 71/100 Time Elapsed: 28.54s
# Training Cost: 0.00049754 Validation Cost: 0.12317891 Training Accuracy: 0.9999 Validation Accuracy: 0.9920
# Epoch 72/100 Time Elapsed: 27.93s
# Training Cost: 0.00063185 Validation Cost: 0.12454887 Training Accuracy: 0.9999 Validation Accuracy: 0.9912
# Epoch 73/100 Time Elapsed: 27.98s
# Training Cost: 0.00074419 Validation Cost: 0.12867710 Training Accuracy: 0.9999 Validation Accuracy: 0.9922
# Epoch 74/100 Time Elapsed: 27.91s
# Training Cost: 0.00055760 Validation Cost: 0.12607756 Training Accuracy: 0.9998 Validation Accuracy: 0.9922
# Epoch 75/100 Time Elapsed: 29.12s
# Training Cost: 0.00047985 Validation Cost: 0.12318929 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 76/100 Time Elapsed: 27.77s
# Training Cost: 0.00075021 Validation Cost: 0.12518814 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 77/100 Time Elapsed: 27.89s
# Training Cost: 0.00062087 Validation Cost: 0.12758815 Training Accuracy: 0.9998 Validation Accuracy: 0.9912
# Epoch 78/100 Time Elapsed: 27.05s
# Training Cost: 0.00055143 Validation Cost: 0.12768519 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 79/100 Time Elapsed: 28.99s
# Training Cost: 0.00050026 Validation Cost: 0.13154848 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 80/100 Time Elapsed: 26.09s
# Training Cost: 0.00055979 Validation Cost: 0.12856640 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 81/100 Time Elapsed: 27.01s
# Training Cost: 0.00042300 Validation Cost: 0.12862866 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 82/100 Time Elapsed: 29.04s
# Training Cost: 0.00060299 Validation Cost: 0.12799783 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 83/100 Time Elapsed: 28.50s
# Training Cost: 0.00041520 Validation Cost: 0.13089666 Training Accuracy: 0.9999 Validation Accuracy: 0.9918
# Epoch 84/100 Time Elapsed: 28.17s
# Training Cost: 0.00065517 Validation Cost: 0.13008098 Training Accuracy: 0.9998 Validation Accuracy: 0.9916
# Epoch 85/100 Time Elapsed: 28.99s
# Training Cost: 0.00048755 Validation Cost: 0.12967266 Training Accuracy: 0.9999 Validation Accuracy: 0.9918
# Epoch 86/100 Time Elapsed: 28.15s
# Training Cost: 0.00077824 Validation Cost: 0.13037343 Training Accuracy: 0.9998 Validation Accuracy: 0.9916
# Epoch 87/100 Time Elapsed: 27.93s
# Training Cost: 0.00068388 Validation Cost: 0.12953691 Training Accuracy: 0.9998 Validation Accuracy: 0.9916
# Epoch 88/100 Time Elapsed: 28.90s
# Training Cost: 0.00054409 Validation Cost: 0.12842584 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 89/100 Time Elapsed: 28.63s
# Training Cost: 0.00045821 Validation Cost: 0.13037239 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 90/100 Time Elapsed: 28.12s
# Training Cost: 0.00077015 Validation Cost: 0.12954299 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 91/100 Time Elapsed: 29.75s
# Training Cost: 0.00049028 Validation Cost: 0.13016352 Training Accuracy: 0.9999 Validation Accuracy: 0.9918
# Epoch 92/100 Time Elapsed: 27.98s
# Training Cost: 0.00084139 Validation Cost: 0.13055928 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 93/100 Time Elapsed: 28.81s
# Training Cost: 0.00041078 Validation Cost: 0.13113636 Training Accuracy: 0.9999 Validation Accuracy: 0.9918
# Epoch 94/100 Time Elapsed: 28.71s
# Training Cost: 0.00047171 Validation Cost: 0.13171968 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 95/100 Time Elapsed: 27.54s
# Training Cost: 0.00038849 Validation Cost: 0.13103065 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 96/100 Time Elapsed: 28.55s
# Training Cost: 0.00056230 Validation Cost: 0.13127217 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 97/100 Time Elapsed: 27.58s
# Training Cost: 0.00055171 Validation Cost: 0.13214670 Training Accuracy: 0.9999 Validation Accuracy: 0.9916
# Epoch 98/100 Time Elapsed: 26.61s
# Training Cost: 0.00068390 Validation Cost: 0.13167386 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 99/100 Time Elapsed: 26.23s
# Training Cost: 0.00039224 Validation Cost: 0.13125549 Training Accuracy: 0.9999 Validation Accuracy: 0.9914
# Epoch 100/100 Time Elapsed: 29.35s
# Training Cost: 0.00056548 Validation Cost: 0.13058054 Training Accuracy: 0.9999 Validation Accuracy: 0.9912
# Testing Accuracy: 0.9920

# %%
show_costs_graphs(costs_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   del sys.path[0]

# %%
show_accs_graphs(accuracies_history)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   del sys.path[0]
